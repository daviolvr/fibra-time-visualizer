# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Substitua pelo caminho correto do seu arquivo CSV
file_path = '/home/davioliveira/projects/FIBRA-Larces/visualizer/execution_times.csv'  
data = pd.read_csv(file_path)

# Criar DataFrame com os dados
src_tempo_checagem_iptables = data['src_tempo_checagem_iptables']
dst_tempo_checagem_iptables = data['dst_tempo_checagem_iptables']

df = pd.DataFrame({
    "tempo_checagem_iptables": pd.concat([data['src_tempo_checagem_iptables'], data['dst_tempo_checagem_iptables']], ignore_index=True)
})

print(df)
# Out:
#     tempo_checagem_iptables
# 0                 44.944525
# 1                 13.124943
# 2                 10.716200
# 3                 31.566858
# 4                 16.825438
# 5                 11.901617
# 6                 61.074495
# 7                  8.090973
# 8                 37.226677
# 9                 59.917212
# 10                55.182457
# 11                19.142151
# 12                49.389362
# 13                23.547411
# 14                25.873184
# 15                21.654606
# 16                26.185036
# 17               125.337362
# 18                18.119097
# 19                49.105644
# 20                51.904678
# 21               821.429968
# 22                46.479702
# 23                30.978680
# 24                10.859251
# 25                 8.184910
# 26                11.246443
# 27                15.567780
# 28                14.867306
# 29                20.023823
# 30                 9.995222
# 31                19.118071
# 32                15.716314
# 33                17.356157
# 34                17.440557
# 35                13.532400
# 36                18.937349
# 37                21.430731
# 38                19.960403
# 39                33.284187
# 40                16.731501
# 41                11.675358
# 42                17.881632
# 43                11.722088
# 44              1182.227373
# 45                11.616468

# %%
df.replace(0, np.nan, inplace=True)

# Remover as linhas que contêm NaN
df.dropna(inplace=True, ignore_index=True)

# Exibir o DataFrame com as linhas sem NaN
print(df)
# Out:
#     tempo_checagem_iptables
# 0                 44.944525
# 1                 13.124943
# 2                 10.716200
# 3                 31.566858
# 4                 16.825438
# 5                 11.901617
# 6                 61.074495
# 7                  8.090973
# 8                 37.226677
# 9                 59.917212
# 10                55.182457
# 11                19.142151
# 12                49.389362
# 13                23.547411
# 14                25.873184
# 15                21.654606
# 16                26.185036
# 17               125.337362
# 18                18.119097
# 19                49.105644
# 20                51.904678
# 21               821.429968
# 22                46.479702
# 23                30.978680
# 24                10.859251
# 25                 8.184910
# 26                11.246443
# 27                15.567780
# 28                14.867306
# 29                20.023823
# 30                 9.995222
# 31                19.118071
# 32                15.716314
# 33                17.356157
# 34                17.440557
# 35                13.532400
# 36                18.937349
# 37                21.430731
# 38                19.960403
# 39                33.284187
# 40                16.731501
# 41                11.675358
# 42                17.881632
# 43                11.722088
# 44              1182.227373
# 45                11.616468

# %%
# Calculando média de tempo pra checagem com o IPtables
mean_time = df['tempo_checagem_iptables'].mean()
print(mean_time)
# Out:
# 69.11073041998822

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 5))

# Gráfico de linha para os valores
sns.lineplot(data=df, x=range(len(df)), y="tempo_checagem_iptables", marker="o", label="Checagem IPtables", color="blue")

# Configurações do gráfico
plt.title("Tempo para checagem no IPtables", fontsize=16)
plt.xlabel("Índice", fontsize=12)
plt.ylabel("Tempo (ms)", fontsize=12)
plt.legend(fontsize=12)
plt.tight_layout()

# Exibir o gráfico
plt.show()
